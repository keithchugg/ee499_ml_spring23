# %% [markdown]
# **Instructors**: Prof. Keith Chugg (chugg@usc.edu) & Prof. Antonio Ortega (aortega@usc.edu)
#
# **Notebook**: Written by Prof. Keith Chugg.

# %% [markdown]
# # Multiclass Classifier for MNIST (and Fashion MNIST) Using MLP in TensorFlow
# In this notebook, we will use TensorFlow to train an ANN/MLP for the MNIST/FMNIST datasets we previously explored with an MSE classifier.
#
# This notebook requires Tensorflow to be installed.  To install this, use `pip install tensorflow` or `conda install tensorflow`.  If you have an Nvidia GPU, you can use `conda install tensorflow-gpu` to have it use the GPU.  If you have an M1/M2 Apple chip, use `pip install tensorflow-macos`

# %%
import numpy as np 
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.datasets import fashion_mnist, mnist
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ## Accessing the Data
# First, let's get a function to get the MNIST or FMNIST data.  Previously, we used PyTorch to access the datasets, but TF also has these built in.  So, we should be familiar with this data.

# %%
USE_FASHION_MNIST = False

#### get the daatset

if USE_FASHION_MNIST:
    (train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
    tag_name = 'FashionMNIST'
    label_names = ["top", "trouser", "pullover", "dress", "coat", "sandal", "shirt", "sneaker", "bag", "ankle boot"]
else:
    (train_images, train_labels), (test_images, test_labels) = mnist.load_data()
    tag_name = 'MNIST'
    label_names = [f'{i}' for i in set(test_labels)]

# train_images.shape is (60000, 28, 28)
#test_images.shape (10000, 28, 28)
num_pixels = 28 * 28 
train_images = train_images.reshape( (60000, num_pixels) ).astype(np.float32) / 255.0
test_images = test_images.reshape( (10000, num_pixels) ).astype(np.float32)  / 255.0

# %% [markdown]
# ## ANN/MLP Model Definition
# In TensorFlow, we need to define the model.  Below, we define an ANN that takes a vector of length 784 as input, then has one hidden layer, followed by a SoftMax output layer.

# %%
## Some hyper-parameters for our model
reg_val = 0.001
hidden_nodes = 48


# this uses the Functional API for definning the model
nnet_inputs = Input(shape=(num_pixels,), name='images')
z = Dense(hidden_nodes, activation='relu', kernel_regularizer=regularizers.l2(reg_val), bias_regularizer=regularizers.l2(reg_val), name='hidden')(nnet_inputs)
z = Dense(10, activation='softmax', kernel_regularizer=regularizers.l2(reg_val), bias_regularizer=regularizers.l2(reg_val), name='output')(z)

our_first_model = Model(inputs=nnet_inputs, outputs=z)

# %% [markdown]
# There are a few tools in TF to show the model structure that you created -- `model.summary()` prints a text summary and `tf.keras.plot_model()` produces an image diagram.

# %%
#this will print a summary of the model to the screen
our_first_model.summary()

# this requires a couple of installs:
# brew install graphviz 
# sudo apt install graphviz
# or whatever is your OS package manager...
#
# pip install dot
# ^--- in your environment
#

plot_model(our_first_model, to_file='our_first_model.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  images (InputLayer)         [(None, 784)]             0
#
#  hidden (Dense)              (None, 48)                37680
#
#  output (Dense)              (None, 10)                490
#
# =================================================================
# Total params: 38,170
# Trainable params: 38,170
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Notice that `our_first_model.summary()` printed out the summary of the ANN architecture including the number of trainable parameters.

# %% [markdown]
# ## Training the Model
# Before training, we `compile` which associates a loss function and an optimizer with our model.  We use `SparseCategoricalCrossentropy` loss, which is just MCE when the labels are in integer format -- i.e., for an image for class 8, the label is `8` and `SparseCategoricalCrossentropy` effectively includes the one-hot encoding operation for us.  We also associate a metric of `accuracy` -- this is not used in the training, but we can track it during the training and then produce a learning curve that includes this metric.  Also, two methods for showing how to set the optimizer are shown.  In the first, we set the learning rate explicitly.  This interface is shown in the [TF documentation](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/experimental/SGD).  The second way just uses the SGD optimizer with default values.  The default learning rate is 0.01.

# %%
# define the optimizer explicitly so that we can set the learning rate (as an example)
opt = tf.keras.optimizers.experimental.SGD(learning_rate=0.01)  # thsi si teh default learning rate
our_first_model.compile(optimizer=opt, loss=SparseCategoricalCrossentropy(), metrics=['accuracy']) 
#our_first_model.compile(optimizer='sgd', loss=SparseCategoricalCrossentropy(), metrics=['accuracy'])   ## use defaults for SGD optimizerresults = our_first_model.fit(train_images,  train_labels, batch_size=32, epochs=40, validation_split=0.2)
results = our_first_model.fit(train_images, train_labels, batch_size=32, epochs=40, validation_split=0.2)
# Out:
# Epoch 1/40
# 2023-03-28 18:10:13.386403: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1500/1500 [==============================] - 1s 646us/step - loss: 0.8843 - accuracy: 0.8031 - val_loss: 0.5310 - val_accuracy: 0.8935
# Epoch 2/40
# 1500/1500 [==============================] - 1s 574us/step - loss: 0.5155 - accuracy: 0.8941 - val_loss: 0.4596 - val_accuracy: 0.9091
# Epoch 3/40
# 1500/1500 [==============================] - 1s 587us/step - loss: 0.4644 - accuracy: 0.9067 - val_loss: 0.4281 - val_accuracy: 0.9180
# Epoch 4/40
# 1500/1500 [==============================] - 1s 579us/step - loss: 0.4367 - accuracy: 0.9142 - val_loss: 0.4091 - val_accuracy: 0.9238
# Epoch 5/40
# 1500/1500 [==============================] - 1s 554us/step - loss: 0.4160 - accuracy: 0.9198 - val_loss: 0.3955 - val_accuracy: 0.9273
# Epoch 6/40
# 1500/1500 [==============================] - 1s 549us/step - loss: 0.4000 - accuracy: 0.9237 - val_loss: 0.3809 - val_accuracy: 0.9309
# Epoch 7/40
# 1500/1500 [==============================] - 1s 578us/step - loss: 0.3860 - accuracy: 0.9281 - val_loss: 0.3702 - val_accuracy: 0.9330
# Epoch 8/40
# 1500/1500 [==============================] - 1s 566us/step - loss: 0.3739 - accuracy: 0.9310 - val_loss: 0.3597 - val_accuracy: 0.9358
# Epoch 9/40
# 1500/1500 [==============================] - 1s 557us/step - loss: 0.3632 - accuracy: 0.9336 - val_loss: 0.3525 - val_accuracy: 0.9365
# Epoch 10/40
# 1500/1500 [==============================] - 1s 610us/step - loss: 0.3536 - accuracy: 0.9363 - val_loss: 0.3437 - val_accuracy: 0.9408
# Epoch 11/40
# 1500/1500 [==============================] - 1s 570us/step - loss: 0.3453 - accuracy: 0.9388 - val_loss: 0.3363 - val_accuracy: 0.9426
# Epoch 12/40
# 1500/1500 [==============================] - 1s 559us/step - loss: 0.3375 - accuracy: 0.9412 - val_loss: 0.3313 - val_accuracy: 0.9432
# Epoch 13/40
# 1500/1500 [==============================] - 1s 558us/step - loss: 0.3305 - accuracy: 0.9422 - val_loss: 0.3250 - val_accuracy: 0.9463
# Epoch 14/40
# 1500/1500 [==============================] - 1s 560us/step - loss: 0.3242 - accuracy: 0.9440 - val_loss: 0.3202 - val_accuracy: 0.9460
# Epoch 15/40
# 1500/1500 [==============================] - 1s 567us/step - loss: 0.3183 - accuracy: 0.9452 - val_loss: 0.3147 - val_accuracy: 0.9483
# Epoch 16/40
# 1500/1500 [==============================] - 1s 560us/step - loss: 0.3130 - accuracy: 0.9465 - val_loss: 0.3116 - val_accuracy: 0.9491
# Epoch 17/40
# 1500/1500 [==============================] - 1s 563us/step - loss: 0.3082 - accuracy: 0.9483 - val_loss: 0.3074 - val_accuracy: 0.9497
# Epoch 18/40
# 1500/1500 [==============================] - 1s 564us/step - loss: 0.3039 - accuracy: 0.9492 - val_loss: 0.3030 - val_accuracy: 0.9513
# Epoch 19/40
# 1500/1500 [==============================] - 1s 556us/step - loss: 0.2997 - accuracy: 0.9501 - val_loss: 0.2998 - val_accuracy: 0.9521
# Epoch 20/40
# 1500/1500 [==============================] - 1s 558us/step - loss: 0.2959 - accuracy: 0.9507 - val_loss: 0.2972 - val_accuracy: 0.9532
# Epoch 21/40
# 1500/1500 [==============================] - 1s 570us/step - loss: 0.2922 - accuracy: 0.9527 - val_loss: 0.2945 - val_accuracy: 0.9536
# Epoch 22/40
# 1500/1500 [==============================] - 1s 567us/step - loss: 0.2888 - accuracy: 0.9531 - val_loss: 0.2911 - val_accuracy: 0.9544
# Epoch 23/40
# 1500/1500 [==============================] - 1s 555us/step - loss: 0.2857 - accuracy: 0.9538 - val_loss: 0.2890 - val_accuracy: 0.9544
# Epoch 24/40
# 1500/1500 [==============================] - 1s 562us/step - loss: 0.2829 - accuracy: 0.9543 - val_loss: 0.2866 - val_accuracy: 0.9548
# Epoch 25/40
# 1500/1500 [==============================] - 1s 562us/step - loss: 0.2801 - accuracy: 0.9552 - val_loss: 0.2859 - val_accuracy: 0.9559
# Epoch 26/40
# 1500/1500 [==============================] - 1s 563us/step - loss: 0.2778 - accuracy: 0.9555 - val_loss: 0.2822 - val_accuracy: 0.9567
# Epoch 27/40
# 1500/1500 [==============================] - 1s 560us/step - loss: 0.2754 - accuracy: 0.9565 - val_loss: 0.2804 - val_accuracy: 0.9561
# Epoch 28/40
# 1500/1500 [==============================] - 1s 574us/step - loss: 0.2732 - accuracy: 0.9570 - val_loss: 0.2785 - val_accuracy: 0.9575
# Epoch 29/40
# 1500/1500 [==============================] - 1s 567us/step - loss: 0.2711 - accuracy: 0.9577 - val_loss: 0.2766 - val_accuracy: 0.9585
# Epoch 30/40
# 1500/1500 [==============================] - 1s 522us/step - loss: 0.2691 - accuracy: 0.9580 - val_loss: 0.2748 - val_accuracy: 0.9577
# Epoch 31/40
# 1500/1500 [==============================] - 1s 560us/step - loss: 0.2674 - accuracy: 0.9583 - val_loss: 0.2732 - val_accuracy: 0.9586
# Epoch 32/40
# 1500/1500 [==============================] - 1s 575us/step - loss: 0.2656 - accuracy: 0.9588 - val_loss: 0.2718 - val_accuracy: 0.9592
# Epoch 33/40
# 1500/1500 [==============================] - 1s 567us/step - loss: 0.2639 - accuracy: 0.9600 - val_loss: 0.2717 - val_accuracy: 0.9585
# Epoch 34/40
# 1500/1500 [==============================] - 1s 560us/step - loss: 0.2622 - accuracy: 0.9606 - val_loss: 0.2704 - val_accuracy: 0.9593
# Epoch 35/40
# 1500/1500 [==============================] - 1s 562us/step - loss: 0.2611 - accuracy: 0.9606 - val_loss: 0.2686 - val_accuracy: 0.9603
# Epoch 36/40
# 1500/1500 [==============================] - 1s 568us/step - loss: 0.2596 - accuracy: 0.9610 - val_loss: 0.2669 - val_accuracy: 0.9604
# Epoch 37/40
# 1500/1500 [==============================] - 1s 584us/step - loss: 0.2584 - accuracy: 0.9618 - val_loss: 0.2662 - val_accuracy: 0.9602
# Epoch 38/40
# 1500/1500 [==============================] - 1s 560us/step - loss: 0.2571 - accuracy: 0.9617 - val_loss: 0.2664 - val_accuracy: 0.9613
# Epoch 39/40
# 1500/1500 [==============================] - 1s 565us/step - loss: 0.2558 - accuracy: 0.9620 - val_loss: 0.2654 - val_accuracy: 0.9606
# Epoch 40/40
# 1500/1500 [==============================] - 1s 573us/step - loss: 0.2547 - accuracy: 0.9621 - val_loss: 0.2643 - val_accuracy: 0.9603

# %% [markdown]
# ## Visualizing the Training (Learning Curves)

# %%
# plot our learning curves
# results.history is a dictionary
loss = results.history['loss']
val_loss = results.history['val_loss']
acc = results.history['accuracy']
val_acc = results.history['val_accuracy']

epochs = np.arange(len(loss))

plt.figure()
plt.plot(epochs, loss, label='loss')
plt.plot(epochs, val_loss, label='val_loss')
plt.xlabel('epochs')
plt.ylabel('Multiclass Cross Entropy Loss')
plt.title(f'Loss with{hidden_nodes} Hidden; Regularizer: {reg_val : 3.2g}')
plt.legend()
# plt.savefig(f'learning_loss_R_{reg_val}_D_{dropout_rate}_H_{hidden_nodes}.png', dpi=256)


plt.figure()
plt.plot(epochs, acc, label='acc')
plt.plot(epochs, val_acc, label='val_acc')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.title(f'Accuracy with {hidden_nodes} Hidden; Regularizer: {reg_val : 3.2g}')
plt.legend()
# plt.savefig(f'learning_acc_R_{reg_val}_D_{dropout_rate}_H_{hidden_nodes}.png', dpi=256)

# %% [markdown]
# ## Evaluating on the Test Data
#
# Just to show how to do this, let's save out model and then reload it.
#
# Then, let's evaluate our model on the test dataset.  Then, let's produce a confusion matrix and also do some random sampling to see what our errors may look like.  For this visualization, we need some additional libraries.

# %%
from tensorflow.keras.models import load_model

our_first_model.save(f'{tag_name}_trained.hdf5')
model_copy = load_model(f'{tag_name}_trained.hdf5')

# %%
test_loss, test_acc = model_copy.evaluate(test_images,  test_labels, verbose=2)   ## evaluate is for data with labels, but not training
print(f'Test Loss: {test_loss : 3.2f}')
print(f'Test Accuracy: {100 * test_acc : 3.2f}%')
# Out:
# 313/313 - 0s - loss: 0.2614 - accuracy: 0.9585 - 182ms/epoch - 582us/step
# Test Loss:  0.26
# Test Accuracy:  95.85%

# %%
from sklearn.metrics import classification_report, confusion_matrix
import cv2
import seaborn as sns

# %%
classes = np.asarray(label_names)
preds = model_copy.predict(test_images)

testY_classes = classes[test_labels]
testY_decision = classes[preds.argmax(axis=1)]

cm = confusion_matrix(testY_classes, testY_decision, normalize='true')
plt.figure(figsize=(12,12))
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title(f'{tag_name} MLP - Confusion Matrix') 
ax.xaxis.set_ticklabels(label_names); ax.yaxis.set_ticklabels(label_names)
# Out:
# 313/313 [==============================] - 0s 375us/step
# [Text(0, 0.5, '0'),
#  Text(0, 1.5, '1'),
#  Text(0, 2.5, '2'),
#  Text(0, 3.5, '3'),
#  Text(0, 4.5, '4'),
#  Text(0, 5.5, '5'),
#  Text(0, 6.5, '6'),
#  Text(0, 7.5, '7'),
#  Text(0, 8.5, '8'),
#  Text(0, 9.5, '9')]

# %% [markdown]
# Let's look at one input and check the SoftMax output

# %%
# perform inference on a single image:
prediction = model_copy.predict(test_images[0].reshape(1,num_pixels))   ## preditc is for data without labels
prediction = prediction.reshape(10)
class_decision = np.argmax(prediction)
num_classes = 10
for m in range(num_classes):
	if m == class_decision:
		print(f'class{m}:\tclass soft-decisions:{prediction[m] : 3.4f}\t(hard decision)')
	else:
		print(f'class{m}:\tclass soft-decisions:{prediction[m] : 3.4f}')
# Out:
# 1/1 [==============================] - 0s 12ms/step
# class0:	class soft-decisions: 0.0002
# class1:	class soft-decisions: 0.0000
# class2:	class soft-decisions: 0.0003
# class3:	class soft-decisions: 0.0042
# class4:	class soft-decisions: 0.0000
# class5:	class soft-decisions: 0.0001
# class6:	class soft-decisions: 0.0000
# class7:	class soft-decisions: 0.9944	(hard decision)
# class8:	class soft-decisions: 0.0001
# class9:	class soft-decisions: 0.0008

# %% [markdown]
# Finally, let's do some random sampling on the test set and check the label and prediction.  We have a routine for this from the previous notebook.

# %%
from utils.previous_notebooks import create_montage

hard_predictions = np.argmax(preds, axis=1)

display_images = (test_images * 255).reshape((10000, 28, 28))
create_montage(display_images, hard_predictions, label_names, f'img/{tag_name}_test.png', true_labels=test_labels, N=6)
