# %% [markdown]
# **Instructors**: Prof. Keith Chugg (chugg@usc.edu) & Prof. B. Keith Jenkins (jenkins@sipi.usc.edu)
#
# **Notebook**: Written by Prof. Keith Chugg.

# %% [markdown]
# # Multiclass Classifier for MNIST (and Fashion MNIST) Using MLP in TensorFlow
# In this notebook, we will use TensorFlow to train an ANN/MLP for the MNIST/FMNIST datasets we previously explored with an MSE classifier.
#
# This notebook requires Tensorflow to be installed.  To install this, use `pip install tensorflow` or `conda install tensorflow`.  If you have an Nvidia GPU, you can use `conda install tensorflow-gpu` to have it use the GPU.  If you have an M1/M2 Apple chip, use `pip install tensorflow-macos`

# %%
import numpy as np 
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.datasets import fashion_mnist, mnist
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ## Accessing the Data
# First, let's get a function to get the MNIST or FMNIST data.  Previously, we used PyTorch to access the datasets, but TF also has these built in.  So, we should be familiar with this data.

# %%
USE_FASHION_MNIST = True

#### get the daatset

if USE_FASHION_MNIST:
    (train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
    tag_name = 'FashionMNIST'
    label_names = ["top", "trouser", "pullover", "dress", "coat", "sandal", "shirt", "sneaker", "bag", "ankle boot"]
else:
    (train_images, train_labels), (test_images, test_labels) = mnist.load_data()
    tag_name = 'MNIST'
    label_names = [f'{i}' for i in set(test_labels)]

# train_images.shape is (60000, 28, 28)
#test_images.shape (10000, 28, 28)
num_pixels = 28 * 28 
train_images = train_images.reshape( (60000, num_pixels) ).astype(np.float32) / 255.0
test_images = test_images.reshape( (10000, num_pixels) ).astype(np.float32)  / 255.0

# %% [markdown]
# ## ANN/MLP Model Definition
# In TensorFlow, we need to define the model.  Below, we define an ANN that takes a vector of length 784 as input, then has one hidden layer, followed by a SoftMax output layer.

# %%
## tSome hyper-parameters for our model
reg_val = 0.001
hidden_nodes = 48


# this uses the Functional API for definning the model
nnet_inputs = Input(shape=(num_pixels,), name='images')
z = Dense(hidden_nodes, activation='relu', kernel_regularizer=regularizers.l2(reg_val), bias_regularizer=regularizers.l2(reg_val), name='hidden')(nnet_inputs)
z = Dense(10, activation='softmax', kernel_regularizer=regularizers.l2(reg_val), bias_regularizer=regularizers.l2(reg_val), name='output')(z)

our_first_model = Model(inputs=nnet_inputs, outputs=z)

#this will print a summary of the model to the screen
our_first_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  images (InputLayer)         [(None, 784)]             0
#
#  hidden (Dense)              (None, 48)                37680
#
#  output (Dense)              (None, 10)                490
#
# =================================================================
# Total params: 38,170
# Trainable params: 38,170
# Non-trainable params: 0
# _________________________________________________________________

# %%
# this requires a couple of installs:
# brew install graphviz 
# sudo apt install graphviz
# or whatever is your OS package manager...
#
# pip install dot
# ^--- in your environment
#

plot_model(our_first_model, to_file='our_first_model.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# Notice that `our_first_model.summary()` printed out the summary of the ANN architecture including the number of trainable parameters.

# %% [markdown]
# ## Training the Model
# Before training, we `compile` which associates a loss function and an optimizer with our model.  We use `SparseCategoricalCrossentropy` loss, which is just MCE when the labels are in integer format -- i.e., for an image for class 8, the label is `8` and `SparseCategoricalCrossentropy` effectively includes the one-hot encoding operation for us.  We also associate a metric of `accuracy` -- this is not used in the training, but we can track it during the training and then produce a learning curve that includes this metric.

# %%
our_first_model.compile(optimizer='sgd', loss=SparseCategoricalCrossentropy(), metrics=['accuracy'])
results = our_first_model.fit(train_images,  train_labels, batch_size=32, epochs=40, validation_split=0.2)
# Out:
# Epoch 1/40
# 1500/1500 [==============================] - 1s 650us/step - loss: 0.9569 - accuracy: 0.7279 - val_loss: 0.7172 - val_accuracy: 0.8017
# Epoch 2/40
# 1500/1500 [==============================] - 1s 572us/step - loss: 0.6726 - accuracy: 0.8145 - val_loss: 0.6414 - val_accuracy: 0.8210
# Epoch 3/40
# 1500/1500 [==============================] - 1s 631us/step - loss: 0.6188 - accuracy: 0.8307 - val_loss: 0.6101 - val_accuracy: 0.8307
# Epoch 4/40
# 1500/1500 [==============================] - 1s 580us/step - loss: 0.5906 - accuracy: 0.8385 - val_loss: 0.5830 - val_accuracy: 0.8360
# Epoch 5/40
# 1500/1500 [==============================] - 1s 625us/step - loss: 0.5715 - accuracy: 0.8455 - val_loss: 0.5677 - val_accuracy: 0.8403
# Epoch 6/40
# 1500/1500 [==============================] - 1s 623us/step - loss: 0.5562 - accuracy: 0.8491 - val_loss: 0.5605 - val_accuracy: 0.8493
# Epoch 7/40
# 1500/1500 [==============================] - 1s 611us/step - loss: 0.5446 - accuracy: 0.8528 - val_loss: 0.5618 - val_accuracy: 0.8433
# Epoch 8/40
# 1500/1500 [==============================] - 1s 587us/step - loss: 0.5344 - accuracy: 0.8552 - val_loss: 0.5368 - val_accuracy: 0.8542
# Epoch 9/40
# 1500/1500 [==============================] - 1s 596us/step - loss: 0.5256 - accuracy: 0.8575 - val_loss: 0.5368 - val_accuracy: 0.8528
# Epoch 10/40
# 1500/1500 [==============================] - 1s 592us/step - loss: 0.5192 - accuracy: 0.8593 - val_loss: 0.5439 - val_accuracy: 0.8488
# Epoch 11/40
# 1500/1500 [==============================] - 1s 597us/step - loss: 0.5119 - accuracy: 0.8621 - val_loss: 0.5171 - val_accuracy: 0.8588
# Epoch 12/40
# 1500/1500 [==============================] - 1s 583us/step - loss: 0.5057 - accuracy: 0.8628 - val_loss: 0.5225 - val_accuracy: 0.8558
# Epoch 13/40
# 1500/1500 [==============================] - 1s 668us/step - loss: 0.5000 - accuracy: 0.8648 - val_loss: 0.5228 - val_accuracy: 0.8532
# Epoch 14/40
# 1500/1500 [==============================] - 1s 599us/step - loss: 0.4949 - accuracy: 0.8672 - val_loss: 0.5189 - val_accuracy: 0.8583
# Epoch 15/40
# 1500/1500 [==============================] - 1s 579us/step - loss: 0.4905 - accuracy: 0.8672 - val_loss: 0.5015 - val_accuracy: 0.8622
# Epoch 16/40
# 1500/1500 [==============================] - 1s 601us/step - loss: 0.4862 - accuracy: 0.8685 - val_loss: 0.5047 - val_accuracy: 0.8628
# Epoch 17/40
# 1500/1500 [==============================] - 1s 582us/step - loss: 0.4821 - accuracy: 0.8705 - val_loss: 0.5029 - val_accuracy: 0.8635
# Epoch 18/40
# 1500/1500 [==============================] - 1s 589us/step - loss: 0.4788 - accuracy: 0.8708 - val_loss: 0.4968 - val_accuracy: 0.8629
# Epoch 19/40
# 1500/1500 [==============================] - 1s 580us/step - loss: 0.4752 - accuracy: 0.8708 - val_loss: 0.5044 - val_accuracy: 0.8578
# Epoch 20/40
# 1500/1500 [==============================] - 1s 593us/step - loss: 0.4728 - accuracy: 0.8724 - val_loss: 0.4914 - val_accuracy: 0.8668
# Epoch 21/40
# 1500/1500 [==============================] - 1s 584us/step - loss: 0.4695 - accuracy: 0.8738 - val_loss: 0.4919 - val_accuracy: 0.8677
# Epoch 22/40
# 1500/1500 [==============================] - 1s 583us/step - loss: 0.4661 - accuracy: 0.8745 - val_loss: 0.4835 - val_accuracy: 0.8674
# Epoch 23/40
# 1500/1500 [==============================] - 1s 599us/step - loss: 0.4642 - accuracy: 0.8753 - val_loss: 0.4812 - val_accuracy: 0.8688
# Epoch 24/40
# 1500/1500 [==============================] - 1s 597us/step - loss: 0.4613 - accuracy: 0.8758 - val_loss: 0.4821 - val_accuracy: 0.8645
# Epoch 25/40
# 1500/1500 [==============================] - 1s 600us/step - loss: 0.4594 - accuracy: 0.8765 - val_loss: 0.4818 - val_accuracy: 0.8663
# Epoch 26/40
# 1500/1500 [==============================] - 1s 627us/step - loss: 0.4570 - accuracy: 0.8776 - val_loss: 0.4889 - val_accuracy: 0.8658
# Epoch 27/40
# 1500/1500 [==============================] - 1s 637us/step - loss: 0.4547 - accuracy: 0.8784 - val_loss: 0.4749 - val_accuracy: 0.8712
# Epoch 28/40
# 1500/1500 [==============================] - 1s 601us/step - loss: 0.4527 - accuracy: 0.8790 - val_loss: 0.4753 - val_accuracy: 0.8719
# Epoch 29/40
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.4515 - accuracy: 0.8787 - val_loss: 0.4754 - val_accuracy: 0.8697
# Epoch 30/40
# 1500/1500 [==============================] - 1s 589us/step - loss: 0.4503 - accuracy: 0.8800 - val_loss: 0.4729 - val_accuracy: 0.8708
# Epoch 31/40
# 1500/1500 [==============================] - 1s 606us/step - loss: 0.4478 - accuracy: 0.8795 - val_loss: 0.4694 - val_accuracy: 0.8723
# Epoch 32/40
# 1500/1500 [==============================] - 1s 599us/step - loss: 0.4468 - accuracy: 0.8801 - val_loss: 0.4697 - val_accuracy: 0.8717
# Epoch 33/40
# 1500/1500 [==============================] - 1s 614us/step - loss: 0.4449 - accuracy: 0.8806 - val_loss: 0.4809 - val_accuracy: 0.8660
# Epoch 34/40
# 1500/1500 [==============================] - 1s 592us/step - loss: 0.4441 - accuracy: 0.8806 - val_loss: 0.4715 - val_accuracy: 0.8700
# Epoch 35/40
# 1500/1500 [==============================] - 1s 607us/step - loss: 0.4427 - accuracy: 0.8807 - val_loss: 0.4673 - val_accuracy: 0.8737
# Epoch 36/40
# 1500/1500 [==============================] - 1s 594us/step - loss: 0.4417 - accuracy: 0.8812 - val_loss: 0.4852 - val_accuracy: 0.8648
# Epoch 37/40
# 1500/1500 [==============================] - 1s 589us/step - loss: 0.4409 - accuracy: 0.8825 - val_loss: 0.4705 - val_accuracy: 0.8726
# Epoch 38/40
# 1500/1500 [==============================] - 1s 601us/step - loss: 0.4390 - accuracy: 0.8842 - val_loss: 0.4766 - val_accuracy: 0.8682
# Epoch 39/40
# 1500/1500 [==============================] - 1s 601us/step - loss: 0.4379 - accuracy: 0.8843 - val_loss: 0.4824 - val_accuracy: 0.8667
# Epoch 40/40
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.4380 - accuracy: 0.8837 - val_loss: 0.4713 - val_accuracy: 0.8719

# %% [markdown]
# ## Visualizing the Training (Learning Curves)

# %%
# plot our learning curves
# results.history is a dictionary
loss = results.history['loss']
val_loss = results.history['val_loss']
acc = results.history['accuracy']
val_acc = results.history['val_accuracy']

epochs = np.arange(len(loss))

plt.figure()
plt.plot(epochs, loss, label='loss')
plt.plot(epochs, val_loss, label='val_loss')
plt.xlabel('epochs')
plt.ylabel('Multiclass Cross Entropy Loss')
plt.title(f'Loss with{hidden_nodes} Hidden; Regularizer: {reg_val : 3.2g}')
plt.legend()
# plt.savefig(f'learning_loss_R_{reg_val}_D_{dropout_rate}_H_{hidden_nodes}.png', dpi=256)


plt.figure()
plt.plot(epochs, acc, label='acc')
plt.plot(epochs, val_acc, label='val_acc')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.title(f'Accuracy with {hidden_nodes} Hidden; Regularizer: {reg_val : 3.2g}')
plt.legend()
# plt.savefig(f'learning_acc_R_{reg_val}_D_{dropout_rate}_H_{hidden_nodes}.png', dpi=256)

# %% [markdown]
# ## Evaluating on the Test Data
#
# First, let's evaluate our model on the test dataset.  Then, let's  produce a confusion matrix and also do some random sampling to see what our errors may look like.  For this visualization, we need some additional libraries.

# %%
test_loss, test_acc = our_first_model.evaluate(test_images,  test_labels, verbose=2)
print(f'Test Loss: {test_loss : 3.2f}')
print(f'Test Accuracy: {100 * test_acc : 3.2f}%')
# Out:
# 313/313 - 0s - loss: 0.4934 - accuracy: 0.8598 - 127ms/epoch - 405us/step
# Test Loss:  0.49
# Test Accuracy:  85.98%

# %%
from sklearn.metrics import classification_report, confusion_matrix
import cv2
import seaborn as sns

# %%
classes = np.asarray(label_names)
preds = our_first_model.predict(test_images)

testY_classes = classes[test_labels]
testY_decision = classes[preds.argmax(axis=1)]

cm = confusion_matrix(testY_classes, testY_decision, normalize='true')
plt.figure(figsize=(12,12))
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title(f'{tag_name} MLP - Confusion Matrix') 
ax.xaxis.set_ticklabels(label_names); ax.yaxis.set_ticklabels(label_names)
# Out:
# 313/313 [==============================] - 0s 342us/step
# [Text(0, 0.5, 'top'),
#  Text(0, 1.5, 'trouser'),
#  Text(0, 2.5, 'pullover'),
#  Text(0, 3.5, 'dress'),
#  Text(0, 4.5, 'coat'),
#  Text(0, 5.5, 'sandal'),
#  Text(0, 6.5, 'shirt'),
#  Text(0, 7.5, 'sneaker'),
#  Text(0, 8.5, 'bag'),
#  Text(0, 9.5, 'ankle boot')]

# %% [markdown]
# Let's look at one input and check the SoftMax output

# %%
# perform inference on a single image:
prediction = our_first_model.predict(test_images[0].reshape(1,num_pixels))
num_classes = 10
prediction = prediction.reshape(10)
class_decision = np.argmax(prediction)
for m in range(num_classes):
	if m == class_decision:
		print(f'class{m}:\tclass soft-decisions:{prediction[m] : 3.4f}\t(hard decision)')
	else:
		print(f'class{m}:\tclass soft-decisions:{prediction[m] : 3.4f}')
# Out:
# 1/1 [==============================] - 0s 11ms/step
# class0:	class soft-decisions: 0.0001
# class1:	class soft-decisions: 0.0000
# class2:	class soft-decisions: 0.0001
# class3:	class soft-decisions: 0.0000
# class4:	class soft-decisions: 0.0000
# class5:	class soft-decisions: 0.0930
# class6:	class soft-decisions: 0.0002
# class7:	class soft-decisions: 0.1094
# class8:	class soft-decisions: 0.0074
# class9:	class soft-decisions: 0.7898	(hard decision)

# %% [markdown]
# Finally, let's do some random sampling on the test set and check the label and prediction.  We have a routine for this from the previous notebook.

# %%
from utils.previous_notebooks import create_montage

hard_predictions = np.argmax(preds, axis=1)

display_images = (test_images * 255).reshape((10000, 28, 28))
create_montage(display_images, hard_predictions, label_names, f'img/{tag_name}_test.png', true_labels=test_labels, N=6)
